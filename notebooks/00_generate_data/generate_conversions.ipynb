# %%
# %pip install faker
# Out:
# Collecting faker
#   Downloading faker-40.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata in /databricks/python3/lib/python3.12/site-packages (from faker) (2024.1)
# Downloading faker-40.1.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.1 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.1.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from faker import Faker 
import random

# %%
# Setup
random.seed(42)
fake = Faker()
fake.seed_instance(42)

conversions = []

for _ in range(3000):

    conversions.append({
        "conversion_id" : fake.uuid4(),
        "user_id" :  fake.uuid4(),
        "campaign_id" : fake.uuid4(),
        "conversion_date" : fake.date_between("-3m", "today").strftime("%d-%m-%Y"),
        "revenue" : str(round(random.uniform(10, 500), 2))
    }
    )

df_conversions = spark.createDataFrame(conversions)
display(df_conversions.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>campaign_id</th><th>conversion_date</th><th>conversion_id</th><th>revenue</th><th>user_id</th></tr></thead><tbody><tr><td>bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9</td><td>05-01-2026</td><td>bdd640fb-0667-4ad1-9c80-317fa3b1799d</td><td>323.32</td><td>23b8c1e9-3924-46de-beb1-3b9046685257</td></tr><tr><td>8fadc1a6-06cb-4fb3-9a1d-e644815ef6d1</td><td>05-01-2026</td><td>0822e8f3-6c03-4199-972a-846916419f82</td><td>22.26</td><td>3b8faa18-37f8-488b-97fc-695a07a0ca6e</td></tr><tr><td>c241330b-01a9-471f-9e8a-774bcf36d58b</td><td>05-01-2026</td><td>6b65a6a4-8b81-48f6-b38a-088ca65ed389</td><td>144.76</td><td>47378190-96da-4dac-b2ff-5d2a386ecbe0</td></tr><tr><td>6142ea7d-17be-4111-9a2a-73ed562b0f79</td><td>05-01-2026</td><td>47229389-571a-4876-ac30-7511b2b9437a</td><td>119.37</td><td>c37459ee-f50b-4a63-b71e-cd7b27cd8130</td></tr><tr><td>ec1b8ca1-f91e-4d4c-9ff4-9b7889463e85</td><td>05-01-2026</td><td>43b7a3a6-9a8d-4a03-980d-7b71d8f56413</td><td>370.87</td><td>759cde66-bacf-43d0-8b1f-9163ce9ff57f</td></tr></tbody></table></div>

# %% [markdown]
# * Escrita na RAW

# %%
BASE_PATH = "/Volumes/main/lakehouse_marketing/raw"

df_conversions.write\
    .mode("overwrite")\
    .option("header", "true")\
    .csv(f"{BASE_PATH}/conversions")

# %% [markdown]
# * Validação

# %%
dbutils.fs.ls(BASE_PATH)
# Out:
# [FileInfo(path='dbfs:/Volumes/main/lakehouse_marketing/raw/campaigns/', name='campaigns/', size=0, modificationTime=1767694744669),
#  FileInfo(path='dbfs:/Volumes/main/lakehouse_marketing/raw/conversions/', name='conversions/', size=0, modificationTime=1767694744669),
#  FileInfo(path='dbfs:/Volumes/main/lakehouse_marketing/raw/events/', name='events/', size=0, modificationTime=1767694744669),
#  FileInfo(path='dbfs:/Volumes/main/lakehouse_marketing/raw/users/', name='users/', size=0, modificationTime=1767694744669)]
