# %% [markdown]
# # Generate Users
# ---
# O objetivo deste notebook é criar a base de usuários, usaremos a biblioteca `Faker` para simular os dados.
#
# Definimos também a `seed = 42`, a fim de obtermos a mesma reprodutibilidade na geração dos dados.
#
# Campos da tabela **users**:
#
# * **user_id:** *Representa o id do usuário*
# * **email:** *Email do usuários*
# * **country:** *País associado ao usuário*
# * **signup_date:** *data de cadastro*
# * **created_at:** *data de criação*

# %%
# %pip install faker
# Out:
# Requirement already satisfied: faker in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ae69a06a-9ea5-4171-8649-72445d2841a1/lib/python3.12/site-packages (40.1.0)
# Requirement already satisfied: tzdata in /databricks/python3/lib/python3.12/site-packages (from faker) (2024.1)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from faker import Faker
import random

# %% [markdown]
# #### Geração dos Dados

# %%
# Setup
random.seed(42)
fake = Faker()
fake.seed_instance(42)

# Geração de dados (com erro proposital)
users = []

for _ in range(5000):

    users.append({
        "user_id" : fake.uuid4() if random.random() > 0.05 else None,
        "email" : fake.email(),
        "country" : random.choice(["BR", "br", "Brazil", "US", "usa", None]),
        "signup_date" : fake.date_between("-2y", "today").strftime("%Y-%m-%d"),
        "created_at" : fake.iso8601()
    })

df_users = spark.createDataFrame(users)
display(df_users.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>created_at</th><th>email</th><th>signup_date</th><th>user_id</th></tr></thead><tbody><tr><td>BR</td><td>2000-07-16T07:10:59.304001</td><td>john21@example.net</td><td>2025-06-23</td><td>bdd640fb-0667-4ad1-9c80-317fa3b1799d</td></tr><tr><td>br</td><td>2010-02-04T15:22:56.895920</td><td>robinsonwilliam@example.org</td><td>2025-02-12</td><td>07a0ca6e-0822-48f3-ac03-1199972a8469</td></tr><tr><td>null</td><td>1978-12-10T11:42:31.943111</td><td>zlawrence@example.org</td><td>2025-07-06</td><td>386ecbe0-6b65-46a4-8b81-48f6b38a088c</td></tr><tr><td>null</td><td>1990-02-07T03:37:28.052331</td><td>susanrogers@example.org</td><td>2024-10-02</td><td>27cd8130-4722-4389-971a-a8766c307511</td></tr><tr><td>BR</td><td>1986-06-02T07:56:45.634285</td><td>blairamanda@example.com</td><td>2024-02-25</td><td>ce9ff57f-43b7-43a6-9a8d-ca03580d7b71</td></tr></tbody></table></div>

# %% [markdown]
# #### Escrita na RAW
#
# * Criação dos Volumes

# %%
# %sql
CREATE CATALOG IF NOT EXISTS main;
CREATE SCHEMA IF NOT EXISTS main.lakehouse_marketing;

CREATE VOLUME IF NOT EXISTS main.lakehouse_marketing.raw;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# * Escrita na RAW

# %%
BASE_PATH = "/Volumes/main/lakehouse_marketing/raw"

df_users.write\
    .mode("overwrite")\
    .option("header", "true")\
    .csv(f"{BASE_PATH}/users")

# %% [markdown]
# * Validação

# %%
dbutils.fs.ls("/Volumes/main/lakehouse_marketing/raw")
# Out:
# [FileInfo(path='dbfs:/Volumes/main/lakehouse_marketing/raw/users/', name='users/', size=0, modificationTime=1767127496953)]
