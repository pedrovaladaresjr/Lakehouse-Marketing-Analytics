# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %%
BASE_PATH = "/Volumes/main/lakehouse_marketing"
RAW_PATH = f"{BASE_PATH}/raw"
BRONZE_PATH = f"{BASE_PATH}/bronze"

# %%
campaign_schema = StructType([
    StructField("campaign_id", StringType(), True),
    StructField("campaign_name", StringType(), True),
    StructField("channel", StringType(), True),
    StructField("start_date", StringType(), True),
    StructField("end_date", StringType(), True)
])

df_campaigns_raw = spark.read\
                    .schema(campaign_schema)\
                    .option("header", "true")\
                    .csv(f"{RAW_PATH}/campaigns")

# %%
df_campaigns_bronze = df_campaigns_raw\
                        .withColumn("ingestion_timestamp", F.current_timestamp())\
                        .withColumn("source_file", F.col("_metadata.file_path"))

# %% [markdown]
# * Escrita na Bronze

# %%
BRONZE_CAMPAIGNS_PATH = f"{BRONZE_PATH}/campaigns"

df_campaigns_bronze.write\
    .format('delta')\
    .mode('overwrite')\
    .save(BRONZE_CAMPAIGNS_PATH)

# %% [markdown]
# * Validação

# %%
spark.read\
    .format('delta')\
    .load("/Volumes/main/lakehouse_marketing/bronze/campaigns/")\
    .count()
# Out:
# 30

# %%
# display(spark.read\
#     .format("delta")\
#     .load("/Volumes/main/lakehouse_marketing/bronze/campaigns/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>campaign_id</th><th>campaign_name</th><th>channel</th><th>start_date</th><th>end_date</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>eb2263dd-87c5-421e-ac24-a3c5c754108f</td><td>Campaign_0</td><td>EMAIL</td><td>2025-12-29</td><td>2025-12-29</td><td>2026-01-13T11:28:26.615Z</td><td>dbfs:/Volumes/main/lakehouse_marketing/raw/campaigns/part-00000-tid-1294539358196327925-d0716bbd-f4ac-4599-925c-832725649942-420-1-c000.csv</td></tr><tr><td>5cec4eb5-edd9-4831-9ca3-5cfb04fc6d82</td><td>Campaign_1</td><td>SOCIAL</td><td>2025-12-29</td><td>2025-12-29</td><td>2026-01-13T11:28:26.615Z</td><td>dbfs:/Volumes/main/lakehouse_marketing/raw/campaigns/part-00000-tid-1294539358196327925-d0716bbd-f4ac-4599-925c-832725649942-420-1-c000.csv</td></tr><tr><td>3da9c2a9-0ed4-4f1a-bd4c-bf374eb93eff</td><td>Campaign_2</td><td>EMAIL</td><td>2025-12-29</td><td>2025-12-29</td><td>2026-01-13T11:28:26.615Z</td><td>dbfs:/Volumes/main/lakehouse_marketing/raw/campaigns/part-00000-tid-1294539358196327925-d0716bbd-f4ac-4599-925c-832725649942-420-1-c000.csv</td></tr><tr><td>d0e6e660-7c69-4ee1-bb5e-4bcf15ed6269</td><td>Campaign_3</td><td>EMAIL</td><td>2025-12-29</td><td>2025-12-29</td><td>2026-01-13T11:28:26.615Z</td><td>dbfs:/Volumes/main/lakehouse_marketing/raw