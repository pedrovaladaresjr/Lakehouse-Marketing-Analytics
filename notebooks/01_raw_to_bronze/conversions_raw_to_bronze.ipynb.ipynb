# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %%
BASE_PATH = "/Volumes/main/lakehouse_marketing"
RAW_PATH = f"{BASE_PATH}/raw"
BRONZE_PATH = f"{BASE_PATH}/bronze"

# %% [markdown]
# * Definindo Schema e lendo o csv da Raw

# %%
conversions_schema = StructType([
    StructField("conversion_id", StringType(), True),
    StructField("user_id", StringType(), True),
    StructField("campaign_id", StringType(), True),
    StructField("conversion_date", StringType(), True),
    StructField("revenue", StringType(), True)
])

df_conversions_raw = spark.read\
                        .schema(conversions_schema)\
                        .option("header", "true")\
                        .csv(f"{RAW_PATH}/conversions")

# %%
df_conversions_bronze = df_conversions_raw\
                        .withColumn("ingestion_timestamp", F.current_timestamp())\
                        .withColumn("source_file", F.col("_metadata.file_path"))

# %% [markdown]
# * Escrita na Bronze

# %%
BRONZE_CONVERSIONS_PATH = f"{BRONZE_PATH}/conversions"

df_conversions_bronze.write\
    .format('delta')\
    .mode('overwrite')\
    .save(BRONZE_CONVERSIONS_PATH)

# %%
dbutils.fs.ls(BRONZE_CONVERSIONS_PATH)
# Out:
# [FileInfo(path='dbfs:/Volumes/main/lakehouse_marketing/bronze/conversions/_delta_log/', name='_delta_log/', size=0, modificationTime=1768828327886),
#  FileInfo(path='dbfs:/Volumes/main/lakehouse_marketing/bronze/conversions/part-00000-bf4897da-7f4b-4693-84a6-be7c947ef2dd.c000.snappy.parquet', name='part-00000-bf4897da-7f4b-4693-84a6-be7c947ef2dd.c000.snappy.parquet', size=341135, modificationTime=1768828307000)]

# %%
display(spark.read\
    .format("delta")\
    .load(f"{BRONZE_CONVERSIONS_PATH}"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>conversion_id</th><th>user_id</th><th>campaign_id</th><th>conversion_date</th><th>revenue</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9</td><td>05-01-2026</td><td>bdd640fb-0667-4ad1-9c80-317fa3b1799d</td><td>323.32</td><td>23b8c1e9-3924-46de-beb1-3b9046685257</td><td>2026-01-19T13:11:43.218Z</td><td>dbfs:/Volumes/main/lakehouse_marketing/raw/conversions/part-00000-tid-1801806676276530843-a28704a1-d6a2-4e67-ab12-52a317179396-218-1-c000.csv</td></tr><tr><td>8fadc1a6-06cb-4fb3-9a1d-e644815ef6d1</td><td>05-01-2026</td><td>0822e8f3-6c03-4199-972a-846916419f82</td><td>22.26</td><td>3b8faa18-37f8-488b-97fc-695a07a0ca6e</td><td>2026-01-19T13:11:43.218Z</td><td>dbfs:/Volumes/main/lakehouse_marketing/raw/conversions/part-00000-tid-1801806676276530843-a28704a1-d6a2-4e67-ab12-52a317179396-218-1-c000.csv</td></tr><tr><td>c241330b-01a9-471f-9e8a-774bcf36d58b</td><td>05-01-2026</td><td>6b65a6a4-8b81-48f6-b38a-088ca65ed389</td><td>144.76</td><td>47378190-96da-4dac-b2ff-5d2a386ecbe0</td><td>2026-01-19T13:11:43.218Z</td><td>dbfs:/Volumes/main/lakehouse_marketing/raw